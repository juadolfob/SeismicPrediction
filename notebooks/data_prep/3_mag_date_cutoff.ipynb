# %%
import pandas as pd
from model.utils import minimum_year_analysis, b_slope_analysis

# %% [markdown]
# # Analyse df_south

# %%
df_south = pd.read_csv('../../data/DATA_2_south.csv', delimiter=',', parse_dates=['Datetime'])
minimum_year_analysis(df_south, [1974,1988, 2013, 2017],[1960,2023])
b_slope_analysis(df_south, 3.8)
df_south = df_south[df_south.Datetime.dt.year >= 2017]
df_south = df_south[df_south.Magnitude >= 3.8]

# %% [markdown]
# # Analyse df_north

# %%
df_north = pd.read_csv('../../data/DATA_2_north.csv', delimiter=',', parse_dates=['Datetime'])
minimum_year_analysis(df_north, [1974, 1988, 2010],[1965,2023])
b_slope_analysis(df_north, 3.8)
df_north = df_north[df_north.Datetime.dt.year >= 2010]
df_north = df_north[df_north.Magnitude >= 3.8]

# %% [markdown]
# # Save

# %%
df_north.to_csv("../../data/DATA_3_north.csv", index=False)
df_south.to_csv("../../data/DATA_3_south.csv", index=False)
